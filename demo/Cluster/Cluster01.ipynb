# %% [markdown]
# # Cluster Lenses (Demo n° 1)
#
# This demo follows the pattern from [](/demo/Demo01.ipynb),
# and we will not explain constructs known therefrom.
#
# ## Preparation

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from CosmoSim import CosmoSim
from CosmoSim.datagen import SimImage
import CosmoSim.Image as csimg
from CosmoSim import Parameters

# %% [markdown]
# ## First test of Cluster Lenses
#
# We choose the following parameters for the first simulation.

# %%
cfg = { "simulator" : { "model" : "Raytrace", "cropsize" : 256 }
      , 'lens': { "cluster" : "SIE/5/5/8/0.3/45;SIE/-5/-5/8/0.3/45" }
      , 'source': {
            'mode': 'Spherical',
            'sigma': 5,
            'theta': 45,
            'position': 'cartesian'}
      , 'position': { 'x': 11.01, 'y': 0.31 }
      }
param = Parameters( cfg )

# %% [markdown]
# The new element is the lens specification, which is not as user friendly as it was.
# The `cluster` attribute gives a list of lenses separated by semicolon.
# Each constituent lens consists of the lens model (`"SIE"`) and a list of
# lens parameters separated by slash (`/`).  For SIE, these parameters are
# $x$/$y$/$\theta_E$/$f$/$\phi_L$, i.e. position $(x,y)$, Einstein radius,
# ellipticity, and orientation.
#
# Given the parameters, the simulation is as before.

# %%
imsim = SimImage( param )
im = imsim.getImage()
csimg.imshow( im, title="First example of a cluster lens" )
# Out:
# [SimImage] init (verbose=1) ...
# CosmoSim Constructor
# Number of CPU cores: 14
# [SimImage] setParameters()
# [CosmoSim/py] setCluster(SIE/5/5/8/0.3/45;SIE/-5/-5/8/0.3/45)
# SIE : [5.0, 5.0, 8.0, 0.3, 45.0]
# SIE : [-5.0, -5.0, 8.0, 0.3, 45.0]
# [CosmoSim/py] setCluster calls setLens
# setModelMode(Raytrace)
# [initSim] type(row)=<class 'CosmoSim.CLI.Arguments.Parameters'>
# [makeSource] src=Spherical, ltprf0=None, verbose=1
# [makeSource] mode=SourceSpec.Sphere, ltprf=LightProfileSpec.Gaussian
# [SphericalSource] constructor done
# CosmoSim.makeSource() returns (verbose=1)
# setFile /home/georg/etc/python/cosmosim/lib/python3.14/site-packages/CosmoSim/sie05.txt
# ClusterLens::addLens]] 5
# setFile /home/georg/etc/python/cosmosim/lib/python3.14/site-packages/CosmoSim/sie05.txt
# ClusterLens::addLens]] -5
# [CosmoSim::setLens]
# [CosmoSim::setLens] returning
# [CosmoSim.cpp] setModelMode(3 -> 0)
# [setSource]
# [runSim] starting
# [initLens] ellipseratio = 0.5
# switch( lensmode )
# [initLens] ClusterLens - no further init
# [initLens] instantiated lens
# switch( modelmode )
# Running Raytrace Lens (mode=0)
# [initLens] returning
# [configLens] ready for initAlphasBetas
# [ClusterLens.initAlphasBetas] nosuchfile
# [PsiFunctionLens.initAlphasBetas] Amplitudes file /home/georg/etc/python/cosmosim/lib/python3.14/site-packages/CosmoSim/sie05.txt
# [initAlphasBetas] opened file /home/georg/etc/python/cosmosim/lib/python3.14/site-packages/CosmoSim/sie05.txt
# [PsiFunctionLens.initAlphasBetas] Amplitudes file /home/georg/etc/python/cosmosim/lib/python3.14/site-packages/CosmoSim/sie05.txt
# [initAlphasBet
# as] opened file /home/georg/etc/python/cosmosim/lib/python3.14/site-packages/CosmoSim/sie05.txt
# [configLens] done initAlphasBetas
# [CosmoSim.configLens] no sampling
# [SimulatorModel::setNterms] 10 -> 16
# [SimulatorModel::setMaskMode] 0
# [SimulatorModel::setSource] setting source
# [runSim] thread section
# [SimulatorModel::update] Lens: ClusterLens [Lens (Superclass);Lens (Superclass);]
# [SimulatorModel::getSource()]
# [Source::getImage()]
# [Lens::getXi] [11.01, 0.31]
# [Lens] Fix pt it'n 0; xi0=[11.01, 0.31]; Delta eta = 12.4481, 1.50111
# [Lens] Fix pt it'n 1; xi0=[23.4581, 1.81111]; Delta eta = 14.6328, 5.43218
# [Lens] Fix pt it'n 2; xi0=[25.6428, 5.74218]; Delta eta = 14.5835, 7.21965
# [Lens] Fix pt it'n 3; xi0=[25.5935, 7.52965]; Delta eta = 14.4585, 7.92917
# [Lens] Fix pt it'n 4; xi0=[25.4685, 8.23917]; Delta eta = 14.394, 8.20487
# [Lens] Fix pt it'n 5; xi0=[25.404, 8.51487]; Delta eta = 14.3666, 8.31159
# [Lens] Fix pt it'n 6; xi0=[25.3766, 8.62159]; Delta eta = 14.3556, 8.35287
# [Lens] Fix pt it'n 7; xi0=[25.3656, 8.66287]; Delta eta = 14.3513, 8.36884
# [Lens] Good approximation: xi0=[25.3656, 8.66287]; xi1=[25.3613, 8.67884]
# [Lens::getXi] [11.01, 0.31] -> [25.3613, 8.67884]
# [setNu] etaOffset set to zero.
# [SimulatorModel::update] Done updateApparentAbs()
# [SimulatorModel::update] thread section
# [Source::getImage()]
# [SimulatorModel::updateInner()] R=11.0144
# [calculateAlphaBeta] [[25.3613, 8.67884]] ...
# [ClusterLens->calculateAlphaBeta()] 16; [25.3613, 8.67884]
# [PsiFunctionLens.calculateAlphaBeta()] 16; 8 - [25.3613, 8.67884]
# ClusterLens (0, 0) 0/0
# ClusterLens (0, 1) 0/0
# ClusterLens (1, 0) -0.0900536/0
# ClusterLens (1, 1) 0/0
# ClusterLens (1, 2) 0.0711729/0.055173
# ClusterLens (2, 0) 0/0
# ClusterLens (2, 1) 0.00405563/0.00371298
# ClusterLens (2, 2) 0/0
# ClusterLens (2, 3) -0.00215591/-0.00461354
# ClusterLens (3, 0) -0.000211358/0
# ClusterLens (3, 1) 0/0
# ClusterLens (3, 2) -3.94127e-05/-0.000307459
# ClusterLens (3, 3) 0/0
# ClusterLens (3, 4) 1.43548e-06/0.000444554
# ClusterLens (4, 0) 0/0
# ClusterLens (4, 1) 3.23863e-05/2.71273e-05
# ClusterLens (4, 2) 0/0
# ClusterLens (4, 3) -1.31979e-05/2.18404e-05
# ClusterLens (4, 4) 0/0
# ClusterLens (4, 5) 2.07194e-05/-4.8961e-05
# ClusterLens (5, 0) -3.18058e-06/0
# ClusterLens (5, 1) 0/0
# ClusterLens (5, 2) -1.12218e-06/-5.16919e-06
# ClusterLens (5, 3) 0/0
# ClusterLens (5, 4) 2.59027e-06/-1.02593e-06
# ClusterLens (5, 5) 0/0
# ClusterLens (5, 6) -5.73684e-06/5.78223e-06
# ClusterLens (6, 0) 0/0
# ClusterLens (6, 1) 5.78223e-06/5.78223e-06
# ClusterLens (6, 2) 0/0
# ClusterLens (6, 3) 5.78223e-06/5.78223e-06
# ClusterLens (6, 4) 0/0
# ClusterLens (6, 5) 5.78223e-06/5.78223e-06
# ClusterLens (6, 6) 0/0
# ClusterLens (6, 7) 5.78223e-06/5.78223e-06
# ClusterLens (7, 0) 5.78223e-06/5.78223e-06
# ClusterLens (7, 1) 0/0
# ClusterLens (7, 2) 5.78223e-06/5.78223e-06
# ClusterLens (7, 3) 0/0
# ClusterLens (7, 4) 5.78223e-06/5.78223e-06
# ClusterLens (7, 5) 0/0
# ClusterLens (7, 6) 5.78223e-06/5.78223e-06
# ClusterLens (7, 7) 0/0
# ClusterLens (7, 8) 5.78223e-06/5.78223e-06
# ClusterLens (8, 0) 0/0
# ClusterLens (8, 1) 5.78223e-06/5.78223e-06
# ClusterLens (8, 2) 0/0
# ClusterLens (8, 3) 5.78223e-06/5.78223e-06
# ClusterLens (8, 4) 0/0
# ClusterLens (8, 5) 5.78223e-06/5.78223e-06
# ClusterLens (8, 6) 0/0
# ClusterLens (8, 7) 5.78223e-06/5.78223e-06
# ClusterLens (8, 8) 0/0
# ClusterLens (8, 9) 5.78223e-06/5.78223e-06
# ClusterLens (9, 0) 5.78223e-06/5.78223e-06
# ClusterLens (9, 1) 0/0
# ClusterLens (9, 2) 5.78223e-06/5.78223e-06
# ClusterLens (9, 3) 0/0
# ClusterLens (9, 4) 5.78223e-06/5.78223e-06
# ClusterLens (9, 5) 0/0
# ClusterLens (9, 6) 5.78223e-06/5.78223e-06
# ClusterLens (9, 7) 0/0
# ClusterLens (9, 8) 5.78223e-06/5.78223e-06
# ClusterLens (9, 9) 0/0
# ClusterLens (9, 10) 5.78223e-06/5.78223e-06
# ClusterLens (10, 0) 0/0
# ClusterLens (10, 1) 5.78223e-06/5.78223e-06
# ClusterLens (10, 2) 0/0
# ClusterLens (10, 3) 5.78223e-06/5.78223e-06
# ClusterLens (10, 4) 0/0
# ClusterLens (10, 5) 5.78223e-06/5.78223e-06
# ClusterLens (10, 6) 0/0
# ClusterLens (10, 7) 5.78223e-06/5.78223e-06
# ClusterLens (10, 8) 0/0
# ClusterLens (10, 9) 5.78223e-06/5.78223e-06
# ClusterLens (10, 10) 0/0
# ClusterLens (10, 11) 5.78223e-06/5.78223e-06
# ClusterLens (11, 0) 5.78223e-06/5.78223e-06
# ClusterLens (11, 1) 0/0
# ClusterLens (11, 2) 5.78223e-06/5.78223e-06
# ClusterLens (11, 3) 0/0
# ClusterLens (11, 4) 5.78223e-06/5.78223e-06
# ClusterLens (11, 5) 0/0
# ClusterLens (11, 6) 5.78223e-06/5.78223e-06
# ClusterLens (11, 7) 0/0
# ClusterLens (11, 8) 5.78223e-06/5.78223e-06
# ClusterLens (11, 9) 0/0
# ClusterLens (11, 10) 5.78223e-06/5.78223e-06
# ClusterLens (11, 11) 0/0
# ClusterLens (11, 12) 5.78223e-06/5.78223e-06
# ClusterLens (12, 0) 0/0
# ClusterLens (12, 1) 5.78223e-06/5.78223e-06
# ClusterLens (12, 2) 0/0
# ClusterLens (12, 3) 5.78223e-06/5.78223e-06
# ClusterLens (12, 4) 0/0
# ClusterLens (12, 5) 5.78223e-06/5.78223e-06
# ClusterLens (12, 6) 0/0
# ClusterLens (12, 7) 5.78223e-06/5.78223e-06
# ClusterLens (12, 8) 0/0
# ClusterLens (12, 9) 5.78223e-06/5.78223e-06
# ClusterLens (12, 10) 0/0
# ClusterLens (12, 11) 5.78223e-06/5.78223e-06
# ClusterLens (12, 12) 0/0
# ClusterLens (12, 13) 5.78223e-06/5.78223e-06
# ClusterLens (13, 0) 5.78223e-06/5.78223e-06
# ClusterLens (13, 1) 0/0
# ClusterLens (13, 2) 5.78223e-06/5.78223e-06
# ClusterLens (13, 3) 0/0
# ClusterLens (13, 4) 5.78223e-06/5.78223e-06
# ClusterLens (13, 5) 0/0
# ClusterLens (13, 6) 5.78223e-06/5.78223e-06
# ClusterLens (13, 7) 0/0
# ClusterLens (13, 8) 5.78223e-06/5.78223e-06
# ClusterLens (13, 9) 0/0
# ClusterLens (13, 10) 5.78223e-06/5.78223e-06
# ClusterLens (13, 11) 0/0
# ClusterLens (13, 12) 5.78223e-06/5.78223e-06
# ClusterLens (13, 13) 0/0
# ClusterLens (13, 14) 5.78223e-06/5.78223e-06
# ClusterLens (14, 0) 0/0
# ClusterLens (14, 1) 5.78223e-06/5.78223e-06
# ClusterLens (14, 2) 0/0
# ClusterLens (14, 3) 5.78223e-06/5.78223e-06
# ClusterLens (14, 4) 0/0
# ClusterLens (14, 5) 5.78223e-06/5.78223e-06
# ClusterLens (14, 6) 0/0
# ClusterLens (14, 7) 5.78223e-06/5.78223e-06
# ClusterLens (14, 8) 0/0
# ClusterLens (14, 9) 5.78223e-06/5.78223e-06
# ClusterLens (14, 10) 0/0
# ClusterLens (14, 11) 5.78223e-06/5.78223e-06
# ClusterLens (14, 12) 0/0
# ClusterLens (14, 13) 5.78223e-06/5.78223e-06
# ClusterLens (14, 14) 0/0
# ClusterLens (14, 15) 5.78223e-06/5.78223e-06
# ClusterLens (15, 0) 5.78223e-06/5.78223e-06
# ClusterLens (15, 1) 0/0
# ClusterLens (15, 2) 5.78223e-06/5.78223e-06
# ClusterLens (15, 3) 0/0
# ClusterLens (15, 4) 5.78223e-06/5.78223e-06
# ClusterLens (15, 5) 0/0
# ClusterLens (15, 6) 5.78223e-06/5.78223e-06
# ClusterLens (15, 7) 0/0
# ClusterLens (15, 8) 5.78223e-06/5.78223e-06
# ClusterLens (15, 9) 0/0
# ClusterLens (15, 10) 5.78223e-06/5.78223e-06
# ClusterLens (15, 11) 0/0
# ClusterLens (15, 12) 5.78223e-06/5.78223e-06
# ClusterLens (15, 13) 0/0
# ClusterLens (15, 14) 5.78223e-06/5.78223e-06
# ClusterLens (15, 15) 0/0
# ClusterLens (15, 16) 5.78223e-06/5.78223e-06
# ClusterLens (16, 0) 0/0
# ClusterLens (16, 1) 5.78223e-06/5.78223e-06
# ClusterLens (16, 2) 0/0
# ClusterLens (16, 3) 5.78223e-06/5.78223e-06
# ClusterLens (16, 4) 0/0
# ClusterLens (16, 5) 5.78223e-06/5.78223e-06
# ClusterLens (16, 6) 0/0
# ClusterLens (16, 7) 5.78223e-06/5.78223e-06
# ClusterLens (16, 8) 0/0
# ClusterLens (16, 9) 5.78223e-06/5.78223e-06
# ClusterLens (16, 10) 0/0
# ClusterLens (16, 11) 5.78223e-06/5.78223e-06
# ClusterLens (16, 12) 0/0
# ClusterLens (16, 13) 5.78223e-06/5.78223e-06
# ClusterLens (16, 14) 0/0
# ClusterLens (16, 15) 5.78223e-06/5.78223e-06
# ClusterLens (16, 16) 0/0
# ClusterLens (16, 17) 5.78223e-06/5.78223e-06
# [PsiFunctionLens.calculateAlphaBeta()] 16; 8 - [25.3613, 8.67884]
# ClusterLens (0, 0) 0/0
# ClusterLens (0, 1) 0/0
# ClusterLens (1, 0) -0.180107/0
# ClusterLens (1, 1) 0/0
# ClusterLens (1, 2) 0.142346/0.110346
# ClusterLens (2, 0) 0/0
# ClusterLens (2, 1) 0.00811127/0.00742596
# ClusterLens (2, 2) 0/0
# ClusterLens (2, 3) -0.00431182/-0.00922708
# ClusterLens (3, 0) -0.000422717/0
# ClusterLens (3, 1) 0/0
# ClusterLens (3, 2) -7.88254e-05/-0.000614918
# ClusterLens (3, 3) 0/0
# ClusterLens (3, 4) 2.87096e-06/0.000889107
# ClusterLens (4, 0) 0/0
# ClusterLens (4, 1) 6.47727e-05/5.42546e-05
# ClusterLens (4, 2) 0/0
# ClusterLens (4, 3) -2.63957e-05/4.36808e-05
# ClusterLens (4, 4) 0/0
# ClusterLens (4, 5) 4.14388e-05/-9.79219e-05
# ClusterLens (5, 0) -6.36117e-06/0
# ClusterLens (5, 1) 0/0
# ClusterLens (5, 2) -2.24436e-06/-1.03384e-05
# ClusterLens (5, 3) 0/0
# ClusterLens (5, 4) 5.18054e-06/-2.05186e-06
# ClusterLens (5, 5) 0/0
# ClusterLens (5, 6) -1.14737e-05/1.15645e-05
# ClusterLens (6, 0) 0/0
# ClusterLens (6, 1) 1.15645e-05/1.15645e-05
# ClusterLens (6, 2) 0/0
# ClusterLens (6, 3) 1.15645e-05/1.15645e-05
# ClusterLens (6, 4) 0/0
# ClusterLens (6, 5) 1.15645e-05/1.15645e-05
# ClusterLens (6, 6) 0/0
# ClusterLens (6, 7) 1.15645e-05/1.15645e-05
# ClusterLens (7, 0) 1.15645e-05/1.15645e-05
# ClusterLens (7, 1) 0/0
# ClusterLens (7, 2) 1.15645e-05/1.15645e-05
# ClusterLens (7, 3) 0/0
# ClusterLens (7, 4) 1.15645e-05/1.15645e-05
# ClusterLens (7, 5) 0/0
# ClusterLens (7, 6) 1.15645e-05/1.15645e-05
# ClusterLens (7, 7) 0/0
# ClusterLens (7, 8) 1.15645e-05/1.15645e-05
# ClusterLens (8, 0) 0/0
# ClusterLens (8, 1) 1.15645e-05/1.15645e-05
# ClusterLens (8, 2) 0/0
# ClusterLens (8, 3) 1.15645e-05/1.15645e-05
# ClusterLens (8, 4) 0/0
# ClusterLens (8, 5) 1.15645e-05/1.15645e-05
# ClusterLens (8, 6) 0/0
# ClusterLens (8, 7) 1.15645e-05/1.15645e-05
# ClusterLens (8, 8) 0/0
# ClusterLens (8, 9) 1.15645e-05/1.15645e-05
# ClusterLens (9, 0) 1.15645e-05/1.15645e-05
# ClusterLens (9, 1) 0/0
# ClusterLens (9, 2) 1.15645e-05/1.15645e-05
# ClusterLens (9, 3) 0/0
# ClusterLens (9, 4) 1.15645e-05/1.15645e-05
# ClusterLens (9, 5) 0/0
# ClusterLens (9, 6) 1.15645e-05/1.15645e-05
# ClusterLens (9, 7) 0/0
# ClusterLens (9, 8) 1.15645e-05/1.15645e-05
# ClusterLens (9, 9) 0/0
# ClusterLens (9, 10) 1.15645e-05/1.15645e-05
# ClusterLens (10, 0) 0/0
# ClusterLens (10, 1) 1.15645e-05/1.15645e-05
# ClusterLens (10, 2) 0/0
# ClusterLens (10, 3) 1.15645e-05/1.15645e-05
# ClusterLens (10, 4) 0/0
# ClusterLens (10, 5) 1.15645e-05/1.15645e-05
# ClusterLens (10, 6) 0/0
# ClusterLens (10, 7) 1.15645e-05/1.15645e-05
# ClusterLens (10, 8) 0/0
# ClusterLens (10, 9) 1.15645e-05/1.15645e-05
# ClusterLens (10, 10) 0/0
# ClusterLens (10, 11) 1.15645e-05/1.15645e-05
# ClusterLens (11, 0) 1.15645e-05/1.15645e-05
# ClusterLens (11, 1) 0/0
# ClusterLens (11, 2) 1.15645e-05/1.15645e-05
# ClusterLens (11, 3) 0/0
# ClusterLens (11, 4) 1.15645e-05/1.15645e-05
# ClusterLens (11, 5) 0/0
# ClusterLens (11, 6) 1.15645e-05/1.15645e-05
# ClusterLens (11, 7) 0/0
# ClusterLens (11, 8) 1.15645e-05/1.15645e-05
# ClusterLens (11, 9) 0/0
# ClusterLens (11, 10) 1.15645e-05/1.15645e-05
# ClusterLens (11, 11) 0/0
# ClusterLens (11, 12) 1.15645e-05/1.15645e-05
# ClusterLens (12, 0) 0/0
# ClusterLens (12, 1) 1.15645e-05/1.15645e-05
# ClusterLens (12, 2) 0/0
# ClusterLens (12, 3) 1.15645e-05/1.15645e-05
# ClusterLens (12, 4) 0/0
# ClusterLens (12, 5) 1.15645e-05/1.15645e-05
# ClusterLens (12, 6) 0/0
# ClusterLens (12, 7) 1.15645e-05/1.15645e-05
# ClusterLens (12, 8) 0/0
# ClusterLens (12, 9) 1.15645e-05/1.15645e-05
# ClusterLens (12, 10) 0/0
# ClusterLens (12, 11) 1.15645e-05/1.15645e-05
# ClusterLens (12, 12) 0/0
# ClusterLens (12, 13) 1.15645e-05/1.15645e-05
# ClusterLens (13, 0) 1.15645e-05/1.15645e-05
# ClusterLens (13, 1) 0/0
# ClusterLens (13, 2) 1.15645e-05/1.15645e-05
# ClusterLens (13, 3) 0/0
# ClusterLens (13, 4) 1.15645e-05/1.15645e-05
# ClusterLens (13, 5) 0/0
# ClusterLens (13, 6) 1.15645e-05/1.15645e-05
# ClusterLens (13, 7) 0/0
# ClusterLens (13, 8) 1.15645e-05/1.15645e-05
# ClusterLens (13, 9) 0/0
# ClusterLens (13, 10) 1.15645e-05/1.15645e-05
# ClusterLens (13, 11) 0/0
# ClusterLens (13, 12) 1.15645e-05/1.15645e-05
# ClusterLens (13, 13) 0/0
# ClusterLens (13, 14) 1.15645e-05/1.15645e-05
# ClusterLens (14, 0) 0/0
# ClusterLens (14, 1) 1.15645e-05/1.15645e-05
# ClusterLens (14, 2) 0/0
# ClusterLens (14, 3) 1.15645e-05/1.15645e-05
# ClusterLens (14, 4) 0/0
# ClusterLens (14, 5) 1.15645e-05/1.15645e-05
# ClusterLens (14, 6) 0/0
# ClusterLens (14, 7) 1.15645e-05/1.15645e-05
# ClusterLens (14, 8) 0/0
# ClusterLens (14, 9) 1.15645e-05/1.15645e-05
# ClusterLens (14, 10) 0/0
# ClusterLens (14, 11) 1.15645e-05/1.15645e-05
# ClusterLens (14, 12) 0/0
# ClusterLens (14, 13) 1.15645e-05/1.15645e-05
# ClusterLens (14, 14) 0/0
# ClusterLens (14, 15) 1.15645e-05/1.15645e-05
# ClusterLens (15, 0) 1.15645e-05/1.15645e-05
# ClusterLens (15, 1) 0/0
# ClusterLens (15, 2) 1.15645e-05/1.15645e-05
# ClusterLens (15, 3) 0/0
# ClusterLens (15, 4) 1.15645e-05/1.15645e-05
# ClusterLens (15, 5) 0/0
# ClusterLens (15, 6) 1.15645e-05/1.15645e-05
# ClusterLens (15, 7) 0/0
# ClusterLens (15, 8) 1.15645e-05/1.15645e-05
# ClusterLens (15, 9) 0/0
# ClusterLens (15, 10) 1.15645e-05/1.15645e-05
# ClusterLens (15, 11) 0/0
# ClusterLens (15, 12) 1.15645e-05/1.15645e-05
# ClusterLens (15, 13) 0/0
# ClusterLens (15, 14) 1.15645e-05/1.15645e-05
# ClusterLens (15, 15) 0/0
# ClusterLens (15, 16) 1.15645e-05/1.15645e-05
# ClusterLens (16, 0) 0/0
# ClusterLens (16, 1) 1.15645e-05/1.15645e-05
# ClusterLens (16, 2) 0/0
# ClusterLens (16, 3) 1.15645e-05/1.15645e-05
# ClusterLens (16, 4) 0/0
# ClusterLens (16, 5) 1.15645e-05/1.15645e-05
# ClusterLens (16, 6) 0/0
# ClusterLens (16, 7) 1.15645e-05/1.15645e-05
# ClusterLens (16, 8) 0/0
# ClusterLens (16, 9) 1.15645e-05/1.15645e-05
# ClusterLens (16, 10) 0/0
# ClusterLens (16, 11) 1.15645e-05/1.15645e-05
# ClusterLens (16, 12) 0/0
# ClusterLens (16, 13) 1.15645e-05/1.15645e-05
# ClusterLens (16, 14) 0/0
# ClusterLens (16, 15) 1.15645e-05/1.15645e-05
# ClusterLens (16, 16) 0/0
# ClusterLens (16, 17) 1.15645e-05/1.15645e-05
# Time to update(): 83 milliseconds
# [Simulator] Centre Point (17.70,0.69) (Centre of Luminence in Planar Co-ordinates)
# [getImage] centring from parameters: None
# [crop] cropsize=256

# %% [markdown]
# ## Closure
